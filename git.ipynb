# %% [markdown]
# ## change to project directory ##

# %%
import os

os.chdir(f'/content/drive/My Drive/Colab Notebooks/FacialClustering')
current_directory = os.getcwd()
print("Current directory:", current_directory)
# Out:
# Current directory: /content/drive/My Drive/Colab Notebooks/FacialClustering

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/FacialClustering/.git/

# %% [markdown]
# ## git Authentication ##

# %%
# !git config --global credential.helper store
# !git config --global user.name "MAMMAD1381"
# !git config --global user.email "mohammad.m6984@gmail.com"
# !echo "https://MAMMAD1381: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@github.com" > ~/.git-credentials

# %%
# !git remote add origin https://github.com/MAMMAD1381/FacialClustering.git
# Out:
# error: remote origin already exists.

# %%
# !git push --set-upstream origin master

# %% [markdown]
# ## Add files ##

# %%
# !git add .
# Out:
# ^C

# %% [markdown]
# ## Commit ##

# %%
# !git commit -m 'separating the preprocess function into three preproceses and organizing the main.ipynb'
# !git commit
# Out:
# [master a0162fa] adding: pre processing methods including: Normalization, Face Detection, Crop & Resize, Data Balancing
#  179 files changed, 2 insertions(+), 2 deletions(-)
#  create mode 100644 dataset/NormalizedDataset/subject01.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject01.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject01.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject01.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject01.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject01.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject01.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject01.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject01.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject01.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject01.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject02 (1).surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject02 (1).wink.png
#  create mode 100644 dataset/NormalizedDataset/subject02.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject02.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject02.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject02.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject02.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject02.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject02.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject02.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject02.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject02.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject02.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).happy.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).normal.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject03 (1).sad.png
#  create mode 100644 dataset/NormalizedDataset/subject03.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject03.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject03.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject03.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject03.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject03.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject03.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject03.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject03.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject03.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject03.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject04.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject04.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject04.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject04.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject04.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject04.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject04.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject04.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject04.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject04.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject04.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject05.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject05.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject05.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject05.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject05.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject05.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject05.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject05.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject05.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject05.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject05.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject06.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject06.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject06.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject06.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject06.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject06.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject06.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject06.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject06.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject06.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject06.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject07.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject07.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject07.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject07.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject07.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject07.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject07.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject07.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject07.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject07.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject07.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject08.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject08.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject08.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject08.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject08.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject08.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject08.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject08.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject08.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject08.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject08.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject09.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject09.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject09.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject09.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject09.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject09.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject09.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject09.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject09.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject09.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject09.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject10.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject10.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject10.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject10.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject10.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject10.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject10.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject10.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject10.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject10.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject10.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject11.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject11.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject11.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject11.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject11.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject11.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject11.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject11.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject11.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject11.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject11.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject12.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject12.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject12.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject12.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject12.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject12.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject12.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject12.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject12.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject12.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject12.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject13.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject13.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject13.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject13.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject13.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject13.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject13.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject13.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject13.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject13.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject13.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject14.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject14.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject14.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject14.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject14.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject14.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject14.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject14.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject14.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject14.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject14.wink.png
#  create mode 100644 dataset/NormalizedDataset/subject15.centerlight.png
#  create mode 100644 dataset/NormalizedDataset/subject15.glasses.png
#  create mode 100644 dataset/NormalizedDataset/subject15.happy.png
#  create mode 100644 dataset/NormalizedDataset/subject15.leftlight.png
#  create mode 100644 dataset/NormalizedDataset/subject15.noglasses.png
#  create mode 100644 dataset/NormalizedDataset/subject15.normal.png
#  create mode 100644 dataset/NormalizedDataset/subject15.rightlight.png
#  create mode 100644 dataset/NormalizedDataset/subject15.sad.png
#  create mode 100644 dataset/NormalizedDataset/subject15.sleepy.png
#  create mode 100644 dataset/NormalizedDataset/subject15.surprised.png
#  create mode 100644 dataset/NormalizedDataset/subject15.wink.png
#  rewrite git.ipynb (97%)
#  rewrite labels.npy (84%)
#  rewrite main.ipynb (91%)

# %% [markdown]
# ## Push ##

# %%
# !git push -u
# Out:
# Enumerating objects: 170, done.
# Counting objects: 100% (170/170), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (164/164), done.
# Writing objects: 100% (164/164), 4.90 MiB | 3.37 MiB/s, done.
# Total 164 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/MAMMAD1381/FacialClustering.git
#    71807e5..a0162fa  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git rm --cac
# Out:
# rm 'git.ipynb'
