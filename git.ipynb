# %% [markdown]
# ## change to project directory ##

# %%
import os

os.chdir(f'/content/drive/My Drive/Colab Notebooks/FacialClustering')
current_directory = os.getcwd()
print("Current directory:", current_directory)
# Out:
# Current directory: /content/drive/My Drive/Colab Notebooks/FacialClustering

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/FacialClustering/.git/

# %% [markdown]
# ## git Authentication ##

# %%
# !git config --global credential.helper store
# !git config --global user.name "MAMMAD1381"
# !git config --global user.email "mohammad.m6984@gmail.com"
# !echo "https://MAMMAD1381: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@github.com" > ~/.git-credentials

# %%
# !git remote add origin https://github.com/MAMMAD1381/FacialClustering.git
# Out:
# error: remote origin already exists.

# %%
# !git push --set-upstream origin master

# %% [markdown]
# ## Add files ##

# %%
# !git add .

# %% [markdown]
# ## Commit ##

# %%
# !git commit -m 'adding a smaple for project including: feature extraction, dimension reduction, clustering'
# Out:
# [master 014e9f6] adding a smaple for project including: feature extraction, dimension reduction, clustering
#  181 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 .gitignore
#  create mode 100644 Phase 1.pdf
#  create mode 100644 dataset/dataset/subject01.centerlight
#  create mode 100644 dataset/dataset/subject01.glasses
#  create mode 100644 dataset/dataset/subject01.happy
#  create mode 100644 dataset/dataset/subject01.leftlight
#  create mode 100644 dataset/dataset/subject01.noglasses
#  create mode 100644 dataset/dataset/subject01.normal
#  create mode 100644 dataset/dataset/subject01.rightlight
#  create mode 100644 dataset/dataset/subject01.sad
#  create mode 100644 dataset/dataset/subject01.sleepy
#  create mode 100644 dataset/dataset/subject01.surprised
#  create mode 100644 dataset/dataset/subject01.wink
#  create mode 100644 dataset/dataset/subject02 (1).surprised
#  create mode 100644 dataset/dataset/subject02 (1).wink
#  create mode 100644 dataset/dataset/subject02.centerlight
#  create mode 100644 dataset/dataset/subject02.glasses
#  create mode 100644 dataset/dataset/subject02.happy
#  create mode 100644 dataset/dataset/subject02.leftlight
#  create mode 100644 dataset/dataset/subject02.noglasses
#  create mode 100644 dataset/dataset/subject02.normal
#  create mode 100644 dataset/dataset/subject02.rightlight
#  create mode 100644 dataset/dataset/subject02.sad
#  create mode 100644 dataset/dataset/subject02.sleepy
#  create mode 100644 dataset/dataset/subject02.surprised
#  create mode 100644 dataset/dataset/subject02.wink
#  create mode 100644 dataset/dataset/subject03 (1).centerlight
#  create mode 100644 dataset/dataset/subject03 (1).glasses
#  create mode 100644 dataset/dataset/subject03 (1).happy
#  create mode 100644 dataset/dataset/subject03 (1).leftlight
#  create mode 100644 dataset/dataset/subject03 (1).noglasses
#  create mode 100644 dataset/dataset/subject03 (1).normal
#  create mode 100644 dataset/dataset/subject03 (1).rightlight
#  create mode 100644 dataset/dataset/subject03 (1).sad
#  create mode 100644 dataset/dataset/subject03.centerlight
#  create mode 100644 dataset/dataset/subject03.glasses
#  create mode 100644 dataset/dataset/subject03.happy
#  create mode 100644 dataset/dataset/subject03.leftlight
#  create mode 100644 dataset/dataset/subject03.noglasses
#  create mode 100644 dataset/dataset/subject03.normal
#  create mode 100644 dataset/dataset/subject03.rightlight
#  create mode 100644 dataset/dataset/subject03.sad
#  create mode 100644 dataset/dataset/subject03.sleepy
#  create mode 100644 dataset/dataset/subject03.surprised
#  create mode 100644 dataset/dataset/subject03.wink
#  create mode 100644 dataset/dataset/subject04.centerlight
#  create mode 100644 dataset/dataset/subject04.glasses
#  create mode 100644 dataset/dataset/subject04.happy
#  create mode 100644 dataset/dataset/subject04.leftlight
#  create mode 100644 dataset/dataset/subject04.noglasses
#  create mode 100644 dataset/dataset/subject04.normal
#  create mode 100644 dataset/dataset/subject04.rightlight
#  create mode 100644 dataset/dataset/subject04.sad
#  create mode 100644 dataset/dataset/subject04.sleepy
#  create mode 100644 dataset/dataset/subject04.surprised
#  create mode 100644 dataset/dataset/subject04.wink
#  create mode 100644 dataset/dataset/subject05.centerlight
#  create mode 100644 dataset/dataset/subject05.glasses
#  create mode 100644 dataset/dataset/subject05.happy
#  create mode 100644 dataset/dataset/subject05.leftlight
#  create mode 100644 dataset/dataset/subject05.noglasses
#  create mode 100644 dataset/dataset/subject05.normal
#  create mode 100644 dataset/dataset/subject05.rightlight
#  create mode 100644 dataset/dataset/subject05.sad
#  create mode 100644 dataset/dataset/subject05.sleepy
#  create mode 100644 dataset/dataset/subject05.surprised
#  create mode 100644 dataset/dataset/subject05.wink
#  create mode 100644 dataset/dataset/subject06.centerlight
#  create mode 100644 dataset/dataset/subject06.glasses
#  create mode 100644 dataset/dataset/subject06.happy
#  create mode 100644 dataset/dataset/subject06.leftlight
#  create mode 100644 dataset/dataset/subject06.noglasses
#  create mode 100644 dataset/dataset/subject06.normal
#  create mode 100644 dataset/dataset/subject06.rightlight
#  create mode 100644 dataset/dataset/subject06.sad
#  create mode 100644 dataset/dataset/subject06.sleepy
#  create mode 100644 dataset/dataset/subject06.surprised
#  create mode 100644 dataset/dataset/subject06.wink
#  create mode 100644 dataset/dataset/subject07.centerlight
#  create mode 100644 dataset/dataset/subject07.glasses
#  create mode 100644 dataset/dataset/subject07.happy
#  create mode 100644 dataset/dataset/subject07.leftlight
#  create mode 100644 dataset/dataset/subject07.noglasses
#  create mode 100644 dataset/dataset/subject07.normal
#  create mode 100644 dataset/dataset/subject07.rightlight
#  create mode 100644 dataset/dataset/subject07.sad
#  create mode 100644 dataset/dataset/subject07.sleepy
#  create mode 100644 dataset/dataset/subject07.surprised
#  create mode 100644 dataset/dataset/subject07.wink
#  create mode 100644 dataset/dataset/subject08.centerlight
#  create mode 100644 dataset/dataset/subject08.glasses
#  create mode 100644 dataset/dataset/subject08.happy
#  create mode 100644 dataset/dataset/subject08.leftlight
#  create mode 100644 dataset/dataset/subject08.noglasses
#  create mode 100644 dataset/dataset/subject08.normal
#  create mode 100644 dataset/dataset/subject08.rightlight
#  create mode 100644 dataset/dataset/subject08.sad
#  create mode 100644 dataset/dataset/subject08.sleepy
#  create mode 100644 dataset/dataset/subject08.surprised
#  create mode 100644 dataset/dataset/subject08.wink
#  create mode 100644 dataset/dataset/subject09.centerlight
#  create mode 100644 dataset/dataset/subject09.glasses
#  create mode 100644 dataset/dataset/subject09.happy
#  create mode 100644 dataset/dataset/subject09.leftlight
#  create mode 100644 dataset/dataset/subject09.noglasses
#  create mode 100644 dataset/dataset/subject09.normal
#  create mode 100644 dataset/dataset/subject09.rightlight
#  create mode 100644 dataset/dataset/subject09.sad
#  create mode 100644 dataset/dataset/subject09.sleepy
#  create mode 100644 dataset/dataset/subject09.surprised
#  create mode 100644 dataset/dataset/subject09.wink
#  create mode 100644 dataset/dataset/subject10.centerlight
#  create mode 100644 dataset/dataset/subject10.glasses
#  create mode 100644 dataset/dataset/subject10.happy
#  create mode 100644 dataset/dataset/subject10.leftlight
#  create mode 100644 dataset/dataset/subject10.noglasses
#  create mode 100644 dataset/dataset/subject10.normal
#  create mode 100644 dataset/dataset/subject10.rightlight
#  create mode 100644 dataset/dataset/subject10.sad
#  create mode 100644 dataset/dataset/subject10.sleepy
#  create mode 100644 dataset/dataset/subject10.surprised
#  create mode 100644 dataset/dataset/subject10.wink
#  create mode 100644 dataset/dataset/subject11.centerlight
#  create mode 100644 dataset/dataset/subject11.glasses
#  create mode 100644 dataset/dataset/subject11.happy
#  create mode 100644 dataset/dataset/subject11.leftlight
#  create mode 100644 dataset/dataset/subject11.noglasses
#  create mode 100644 dataset/dataset/subject11.normal
#  create mode 100644 dataset/dataset/subject11.rightlight
#  create mode 100644 dataset/dataset/subject11.sad
#  create mode 100644 dataset/dataset/subject11.sleepy
#  create mode 100644 dataset/dataset/subject11.surprised
#  create mode 100644 dataset/dataset/subject11.wink
#  create mode 100644 dataset/dataset/subject12.centerlight
#  create mode 100644 dataset/dataset/subject12.glasses
#  create mode 100644 dataset/dataset/subject12.happy
#  create mode 100644 dataset/dataset/subject12.leftlight
#  create mode 100644 dataset/dataset/subject12.noglasses
#  create mode 100644 dataset/dataset/subject12.normal
#  create mode 100644 dataset/dataset/subject12.rightlight
#  create mode 100644 dataset/dataset/subject12.sad
#  create mode 100644 dataset/dataset/subject12.sleepy
#  create mode 100644 dataset/dataset/subject12.surprised
#  create mode 100644 dataset/dataset/subject12.wink
#  create mode 100644 dataset/dataset/subject13.centerlight
#  create mode 100644 dataset/dataset/subject13.glasses
#  create mode 100644 dataset/dataset/subject13.happy
#  create mode 100644 dataset/dataset/subject13.leftlight
#  create mode 100644 dataset/dataset/subject13.noglasses
#  create mode 100644 dataset/dataset/subject13.normal
#  create mode 100644 dataset/dataset/subject13.rightlight
#  create mode 100644 dataset/dataset/subject13.sad
#  create mode 100644 dataset/dataset/subject13.sleepy
#  create mode 100644 dataset/dataset/subject13.surprised
#  create mode 100644 dataset/dataset/subject13.wink
#  create mode 100644 dataset/dataset/subject14.centerlight
#  create mode 100644 dataset/dataset/subject14.glasses
#  create mode 100644 dataset/dataset/subject14.happy
#  create mode 100644 dataset/dataset/subject14.leftlight
#  create mode 100644 dataset/dataset/subject14.noglasses
#  create mode 100644 dataset/dataset/subject14.normal
#  create mode 100644 dataset/dataset/subject14.rightlight
#  create mode 100644 dataset/dataset/subject14.sad
#  create mode 100644 dataset/dataset/subject14.sleepy
#  create mode 100644 dataset/dataset/subject14.surprised
#  create mode 100644 dataset/dataset/subject14.wink
#  create mode 100644 dataset/dataset/subject15.centerlight
#  create mode 100644 dataset/dataset/subject15.glasses
#  create mode 100644 dataset/dataset/subject15.happy
#  create mode 100644 dataset/dataset/subject15.leftlight
#  create mode 100644 dataset/dataset/subject15.noglasses
#  create mode 100644 dataset/dataset/subject15.normal
#  create mode 100644 dataset/dataset/subject15.rightlight
#  create mode 100644 dataset/dataset/subject15.sad
#  create mode 100644 dataset/dataset/subject15.sleepy
#  create mode 100644 dataset/dataset/subject15.surprised
#  create mode 100644 dataset/dataset/subject15.wink
#  create mode 100644 feature_vectors.npy
#  rewrite git.ipynb (84%)
#  create mode 100644 labels.npy
#  create mode 100644 main.ipynb

# %% [markdown]
# ## Push ##

# %%
# !git push -u
# Out:
# Enumerating objects: 168, done.
# Counting objects: 100% (168/168), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (164/164), done.
# Writing objects: 100% (166/166), 7.35 MiB | 4.83 MiB/s, done.
# Total 166 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/MAMMAD1381/FacialClustering.git
#    d9fed6b..014e9f6  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git reset HEAD^
# Out:
# Unstaged changes after reset:
# M	git.ipynb
