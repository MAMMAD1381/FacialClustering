# %% [markdown]
# ## change to project directory ##

# %%
import os

os.chdir(f'/content/drive/My Drive/Colab Notebooks/FacialClustering')
current_directory = os.getcwd()
print("Current directory:", current_directory)
# Out:
# Current directory: /content/drive/My Drive/Colab Notebooks/FacialClustering

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/FacialClustering/.git/

# %% [markdown]
# ## git Authentication ##

# %%
# !git config --global credential.helper store
# !git config --global user.name "MAMMAD1381"
# !git config --global user.email "mohammad.m6984@gmail.com"
# !echo "https://MAMMAD1381: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@github.com" > ~/.git-credentials

# %%
# !git remote add origin https://github.com/MAMMAD1381/FacialClustering.git
# Out:
# error: remote origin already exists.

# %%
# !git push --set-upstream origin master

# %% [markdown]
# ## Add files ##

# %%
# !git add .

# %% [markdown]
# ## Commit ##

# %%
# !git commit -m 'adding Clustering methods such as: Agglomerative, Gaussian, Spectral, MeanShift. also adding saving_clusters functionality'
# !git commit
# Out:
# [master 957f74d] some changes to git.ipynb
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (84%)

# %% [markdown]
# ## Push ##

# %%
# !git push -u
# Out:
# To https://github.com/MAMMAD1381/FacialClustering.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://github.com/MAMMAD1381/FacialClustering.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git status
# Out:
# Refresh index: 100% (708/708), done.
# On branch master
# Your branch is ahead of 'origin/master' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push -f origin master
# Out:
# Enumerating objects: 329, done.
# Counting objects: 100% (329/329), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (325/325), done.
# Writing objects: 100% (325/325), 19.82 MiB | 5.74 MiB/s, done.
# Total 325 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/MAMMAD1381/FacialClustering.git
#  + 2e3a6c3...957f74d master -> master (forced update)
